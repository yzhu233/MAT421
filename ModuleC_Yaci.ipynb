# %% [markdown]
# <a href="https://colab.research.google.com/github/yzhu233/MAT421/blob/main/Module_C_Yaci.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **19.1 Root Finding Problem Statement**
#
# using the python function to find the root

# %%
import numpy as np
from scipy import optimize

f = lambda x: np.sin(x) - x
r = optimize.fsolve(f, 2)
print("r =", r)

# Verify the solution is a root
result = f(r)
print("result=", result)
# Out:
# r = [2.07167136e-08]
# result= [0.]

# %% [markdown]
# For the function which is no root.
# The maxfev=400 is shown that the function is no root near -2

# %%
f = lambda x: 1/x

r, infodict, ier, mesg = optimize.fsolve(f, -2, full_output=True)
print("r =", r)

result = f(r)
print("result=", result)

print(mesg)
# Out:
# r = [-3.52047359e+83]
# result= [-2.84052692e-84]
# The number of calls to function has reached maxfev = 400.

# %% [markdown]
# **19.2 Tolerance**
#
# In engineering and science, error is a deviation from an expected or computed value. Tolerance is the level of error that is acceptable for an engineering application
#
# ![0742bccdcba2a94e48d695ce010e4b9.png](data:image/png;base64,...)

# %% [markdown]
# **19.3 Bisection Method**
#
# ![ebd057a595e96033304968c9f6c132f.png](data:image/png;base64,...)

# %%
import numpy as np

def my_bisection(f, a, b, tol):
  if np.sign(f(a)) == np.sign(f(b)):
    raise Exception(
        "The scalars a and b do not bound a root")
    
  m = (a + b)/2

  if np.abs(f(m)) < tol:
    return m
  elif np.sign(f(a)) == np.sign(f(m)):
    return my_bisection(f, m, b, tol)
  elif np.sign(f(b)) == np.sign(f(m)):
    return my_bisection(f, a, m, tol)

# %%
f = lambda x : x**2 - 5
r1 = my_bisection(f, 0, 5, 0.1)
print("r1 =", r1)
r01 = my_bisection(f, 0, 5, 0.01)
print("r01 =", r01)

print("f(r1) =", f(r1))
print("f(r2) =", f(r01))
# Out:
# r1 = 2.2265625
# r01 = 2.236328125
# f(r1) = -0.04241943359375
# f(r2) = 0.001163482666015625

# %% [markdown]
# **19.4 Newton-Raphson Method**
#
#
# ![69f1a581e135fdbb200344ab52c2d57.png](data:image/png;base64,...)

# %%
import numpy as np

f = lambda x: x**2 - 2
f_prime = lambda x: 2*x
newton_raphson = 1.4 - (f(1.4))/(f_prime(1.4))

print("newton_raphson =", newton_raphson)
print("sqrt(2) =", np.sqrt(2))

def my_newton(f, df, x0, tol):
    # output is an estimation of the root of f 
    # using the Newton Raphson method
    # recursive implementation
    if abs(f(x0)) < tol:
        return x0
    else:
        return my_newton(f, df, x0 - f(x0)/df(x0), tol)
estimate = my_newton(f, f_prime, 1.5, 1e-6)
print("estimate =", estimate)
print("sqrt(2) =", np.sqrt(2))
# Out:
# newton_raphson = 1.4142857142857144
# sqrt(2) = 1.4142135623730951
# estimate = 1.4142135623746899
# sqrt(2) = 1.4142135623730951

# %%
x0 = 0.29
x1 = x0-(x0**3+3*x0**2-2*x0-5)/(3*x0**2+6*x0-2)
print("x1 =", x1)
# Out:
# x1 = -688.4516883116648

# %% [markdown]
# **19.5 Root Finding in python**

# %%
from scipy.optimize import fsolve
f = lambda x: x**3-100*x**2-x+100

fsolve(f, [2, 80])
# Out:
# array([  1., 100.])
